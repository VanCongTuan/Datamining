# %%
import pandas as pd
from shapely.geometry import Polygon
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
# Tạo một hình vẽ
fig = plt.figure(figsize=(10, 8))

# Tạo một trục bản đồ với hệ tọa độ Plate Carree
ax = plt.axes(projection=ccrs.PlateCarree())

# Vẽ ranh giới châu lục châu Á
ax.add_feature(cfeature.BORDERS)

# Tùy chỉnh giới hạn hiển thị của bản đồ
ax.set_extent([0, 150, -10, 40])

# Vẽ các quốc gia
countries = cfeature.NaturalEarthFeature(category='cultural', name='admin_0_countries', scale='50m', facecolor='none', edgecolor='gray')
ax.add_feature(countries)

# Ghi tên các quốc gia
ax.add_feature(cfeature.NaturalEarthFeature(category='cultural', name='admin_0_countries', scale='50m', facecolor='none', edgecolor='none'))

ax.add_feature(cfeature.BORDERS, linewidth=0.5)
ax.add_feature(cfeature.STATES, linewidth=0.2)

# Add gridlines
ax.gridlines(draw_labels=True, linewidth=0.2, color='gray', alpha=0.5, linestyle='--')
# Tạo một hình vẽ
fig = plt.figure(figsize=(10, 8))
ax.set_title('Map of Asia')
# Tạo điểm tại vị trí (longitude, latitude)


universities5 = [
    ('Chiba University', 35.6075, 140.1060),
    ('Hiroshima University', 34.3974, 132.4737),
    ('Hokkaido University', 43.0686, 141.3450),
    ('Kanazawa University', 36.5613, 136.6568),
    ('Keio University', 35.6688, 139.7147),
    ('Kobe University', 34.7269, 135.2336),
    ('Kyoto University', 35.0255, 135.7808),
    ('Kyushu University', 33.5950, 130.2209),
    ('Nagoya University', 35.1558, 136.9229),
    ('Nihon University', 35.7190, 139.7606),
    ('Niigata University', 37.9025, 139.0231),
    ('Okayama University', 34.6556, 133.9199),
    ('Osaka University', 34.9345, 135.5076),
    ('Tohoku University', 38.2554, 140.8995),
    ('Tokyo Institute of Technology', 35.6082, 139.6833),
    ('Tokyo Medical and Dental University', 35.7009, 139.7623),
    ('University of Tokyo', 35.7128, 139.7625),
    ('University of Tsukuba', 36.1046, 140.0889),
    ('Waseda University', 35.7090, 139.7190)
]
for university in universities5:
    name, lat, lon = university
    ax.plot(lon, lat, 'ro', markersize=5,color='yellow')

universities = [
    ('Beihang University', 39.9675, 116.3497),
    ('Beijing Institute of Technology', 39.9622, 116.3620),
    ('Beijing Normal University', 39.9615, 116.3667),
    ('Central South University', 28.1625, 112.9381),
   ('China Agricultural University', 40.0004, 116.3220),
    ('Chinese University of Hong Kong', 22.4193, 114.2078),
    ('Chongqing University', 29.5628, 106.5527),
    ('City University of Hong Kong', 22.3370, 114.1725),
    ('Dalian University of Technology', 38.9194, 121.6137),
    ('East China Normal University', 31.2286, 121.4181),
    ('Fudan University', 31.2989, 121.5015),
    ('Harbin Institute of Technology', 45.7316, 126.6424),
    ('Hong Kong Baptist University', 22.3371, 114.1816),
    ('Hong Kong Polytechnic University', 22.3045, 114.1795),
    ('Hong Kong University of Science and Technology', 22.3375, 114.2637),
    ('Huazhong University of Science and Technology', 30.5161, 114.4244),
    ('Hunan University', 28.1866, 112.9389),
    ('Jilin University', 43.8378, 125.3259),
    ('Lanzhou University', 36.0603, 103.8343),
    ('Nanjing University', 32.0603, 118.7969),
    ('Nankai University', 39.1204, 117.1979),
    ('Northwestern Polytechnical University', 34.2315, 108.9156),
    ('Peking University', 39.9929, 116.3059),
    ('Renmin University of China', 39.9623, 116.3174),
    ('Shandong University', 36.6683, 117.0485),
    ('Shanghai Jiao Tong University', 31.2000, 121.4322),
    ('Shanghai University', 31.2948, 121.5042),
    ('Sichuan University', 30.6586, 104.0646),
    ('Soochow University', 31.2986, 120.6310),
    ('South China University of Technology', 23.0541, 113.3967),
    ('Southeast University', 32.0583, 118.7698),
    ('Sun Yat-Sen University', 23.0977, 113.3241),
    ('Tianjin University', 39.1302, 117.1765),
    ('Tongji University', 31.2850, 121.2150),
    ('Tsinghua University', 40.0039, 116.3265),
    ('University of Electronic Science and Technology of China', 30.5475, 104.0687),
    ('University of Hong Kong', 22.2830, 114.1370),
    ('University of Science and Technology Beijing', 39.9562, 116.3553),
    ('University of Science and Technology of China', 31.8282, 117.2248),
    ('Wuhan University', 30.5370, 114.3630),
    ('Xiamen University', 24.4468, 118.0955),
    ('Xi\'an Jiaotong University', 34.2331, 108.8969),
    ('Zhejiang University', 30.2672, 120.1331),
    ('Zhengzhou University', 34.8155, 113.5349)
   
]

# Truy cập tọa độ các trường
for university in universities:
    name, lat, lon = university
    ax.plot(lon, lat, 'ro', markersize=5)


universities1 = [
    ('Indian Institute of Science', 13.0225, 77.5692),
    ('Indian Institute of Technology Bombay', 19.1334, 72.9154),
    ('Indian Institute of Technology Kanpur', 26.5124, 80.2337),
    ('Indian Institute of Technology Kharagpur', 22.3140, 87.3105),
    ('Indian Institute of Technology Madras', 12.9900, 80.2336),
    ('University of Delhi', 28.6862, 77.2208)
]
for university in universities1:
    name, lat, lon = university
    ax.plot(lon, lat, 'ro', markersize=5,color='cyan')

universities2 = [
    ('University of Indonesia', -6.3621, 106.8243),
]
for university in universities2:
    name, lat, lon = university
    ax.plot(lon, lat, 'ro', markersize=5,color='black')
# Hiển thị bản đồ
universities3 = [
    ('Islamic Azad University, Shirvan', 37.9476, 47.5317),
    ('Tehran University of Medical Sciences', 35.7050, 51.4074),
    ('University of Tehran', 35.7248, 51.3881)
]
for university in universities3:
    name, lat, lon = university
    ax.plot(lon, lat, 'ro', markersize=5,color='blue')


universities4 = [
    ('Bar-Ilan University', 32.0742, 34.8174),
    ('Ben-Gurion University of the Negev', 31.2458, 34.7970),
    ('Hebrew University of Jerusalem', 31.7764, 35.2035),
    ('Technion - Israel Institute of Technology', 32.7775, 35.0212),
    ('Tel Aviv University', 32.1136, 34.8046),
    ('University of Haifa', 32.7688, 35.0205),
    ('Weizmann Institute of Science', 31.8130, 34.7782)
]
for university in universities4:
    name, lat, lon = university
    ax.plot(lon, lat, 'ro', markersize=5,color='green')

universities6 = [
    ('University of Malaya', 3.1186, 101.6538)
]

for university in universities6:
    name, lat, lon = university
    ax.plot(lon, lat, 'ro', markersize=5,color='m')

universities7 = [
    ('King Saud University', 24.7236, 46.6156)
]

for university in universities7:
    name, lat, lon = university
    ax.plot(lon, lat, 'ro', markersize=5,color='green')

universities8 = [
    ('Nanyang Technological University', 1.3483, 103.6831),
    ('National University of Singapore', 1.2966, 103.7764)
]

for university in universities8:
    name, lat, lon = university
    ax.plot(lon, lat, 'ro', markersize=5,color='brown')
universities9 = [
    ('National Cheng Kung University', 22.9970, 120.2180),
    ('National Chiao Tung University', 24.7914, 120.9985),
    ('National Taiwan University', 25.0173, 121.5399),
    ('National Tsing Hua University', 24.7945, 120.9925)
]
for university in universities9:
    name, lat, lon = university
    ax.plot(lon, lat, 'ro', markersize=5,color='gray')

universities10 = [
    ('Ankara University', 39.8647, 32.8450),
    ('Hacettepe University', 39.9075, 32.8604),
    ('Istanbul University', 41.0082, 28.9744),
    ('Middle East Technical University', 39.8897, 32.7802)
]
for university in universities10:
    name, lat, lon = university
    ax.plot(lon, lat, 'ro', markersize=5,color='orange')

universities11 = [
    ('Chulalongkorn University', 13.7367, 100.5309),
    ('Mahidol University', 13.8063, 100.5395)
]

for university in universities11:
    name, lat, lon = university
    ax.plot(lon, lat, 'ro', markersize=5,color='pink')


plt.show()
# Out:
# C:\Users\TUAN\AppData\Local\Temp\ipykernel_24728\3995522832.py:59: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(lon, lat, 'ro', markersize=5,color='yellow')
# C:\Users\TUAN\AppData\Local\Temp\ipykernel_24728\3995522832.py:125: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(lon, lat, 'ro', markersize=5,color='cyan')
# C:\Users\TUAN\AppData\Local\Temp\ipykernel_24728\3995522832.py:132: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(lon, lat, 'ro', markersize=5,color='black')
# ...

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
# Create a figure and a set of subplots
fig, ax = plt.subplots(figsize=(10, 6), subplot_kw=dict(projection=ccrs.PlateCarree()))

# Set the extent of the map to focus on Europe
ax.set_extent([-25, 60, 0, 70], crs=ccrs.PlateCarree())

# Add coastlines, countries, and states/provinces
ax.coastlines(resolution='10m', linewidth=0.5)
ax.add_feature(cfeature.BORDERS, linewidth=0.5)
ax.add_feature(cfeature.STATES, linewidth=0.2)

# Add gridlines
ax.gridlines(draw_labels=True, linewidth=0.2, color='gray', alpha=0.5, linestyle='---')

# Set the title of the map
ax.set_title('Map of Europe')

universities = [
    ('University of Helsinki', 60.1699, 24.9384)
]
for field in universities:
    name, lat, lon = field
    ax.plot(lon, lat, 'ro', markersize=5,color='pink')

plt.show()
# Out:
# C:\Users\TUAN\AppData\Local\Temp\ipykernel_624\3629039067.py:26: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(lon, lat, 'ro', markersize=5,color='pink')

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
# Create a figure and a set of subplots
fig, ax = plt.subplots(figsize=(10, 6), subplot_kw=dict(projection=ccrs.PlateCarree()))

# Set the ext  the map to focus on Europe
ax.set_extent([-25, 50, 20, 80], crs=ccrs.PlateCarree())

# Add coastlines, countries, and states/provinces
ax.coastlines(resolution='10m', linewidth=0.5)
ax.add_feature(cfeature.BORDERS, linewidth=0.5)
ax.add_feature(cfeature.STATES, linewidth=0.2)

# Add gridlines
ax.gridlines(draw_labels=True, linewidth=0.2, color='gray', alpha=0.5, linestyle='--')

# Set the title of the map
ax.set_title('Map of Europe')



universities = [
    ('University of Vienna', 48.2132, 16.3600)
]

for field in universities:
    name, lat, lon = field
    ax.plot(lon, lat, 'ro', markersize=5, color='red')
universities = [
    ('Catholic University of Leuven', 50.8775, 4.7081),
    ('Catholic University of Louvain', 50.6687, 4.6144),
    ('Ghent University', 51.0204, 3.7109),
    ('University of Liege', 50.6337, 5.5675)
]
for field in universities:
    name, lat, lon = field
    ax.plot(lon, lat, 'ro', markersize=5,color='cyan')

universities = [
    ('Charles University', 50.0878, 14.4205)
]
for field in universities:
    name, lat, lon = field
    ax.plot(lon, lat, 'ro', markersize=5,color='brown')

universities = [
    ('Aarhus University', 56.1720, 10.1885),
    ('Technical University of Denmark', 55.7827, 12.5213),
    ('University of Copenhagen', 55.6794, 12.5722)
]
for field in universities:
    name, lat, lon = field
    ax.plot(lon, lat, 'ro', markersize=5,color='orange')

universities = [
    ('University of Helsinki', 60.1699, 24.9384)
]
for field in universities:
    name, lat, lon = field
    ax.plot(lon, lat, 'ro', markersize=5,color='pink')

universities = [
    ('École Normale Supérieure, Paris', 48.8462, 2.3422),
    ('École Normale Supérieure de Lyon', 45.7274, 4.8241)
]
for field in universities:
    name, lat, lon = field
    ax.plot(lon, lat, 'ro', markersize=5,color='green')


universities = [
    ('Dresden University of Technology', 51.0287, 13.7267),
    ('Free University of Berlin', 52.4525, 13.2894),
    ('Heidelberg University - Germany', 49.4077, 8.6908),
    ('Humboldt University of Berlin', 52.5200, 13.4050),
    ('Johannes Gutenberg University Mainz', 50.0000, 8.2711),
    ('Karlsruhe Institute of Technology', 49.0139, 8.4044),
    ('Kiel University', 54.3511, 10.1347),
    ('Ruhr University Bochum', 51.4475, 7.2608),
    ('RWTH Aachen University', 50.7781, 6.0602),
    ('Technical University of Berlin', 52.4518, 13.2975),
    ('Technical University of Munich', 48.1490, 11.5670),
    ('University of Bonn', 50.7339, 7.0975),
    ('University of Cologne', 50.9288, 6.9416),
    ('University of Erlangen Nuremberg', 49.5978, 11.0048),
    ('University of Freiburg', 47.9972, 7.8426),
    ('University of Göttingen', 51.5351, 9.9357),
    ('University of Hamburg', 53.5666, 9.9840),
    ('University of Leipzig', 51.3381, 12.3811),
    ('University of Munich', 48.1486, 11.5804),
    ('University of Münster', 51.9623, 7.6257),
    ('University of Tübingen', 48.5236, 9.0556),
    ('University of Würzburg', 49.7980, 9.9356)
]

for field in universities:
    name, lat, lon = field
    ax.plot(lon, lat, 'ro', markersize=5, color='b')

universities = [
    ('National and Kapodistrian University of Athens', 37.9795, 23.7314)
]
for field in universities:
    name, lat, lon = field
    ax.plot(lon, lat, 'ro', markersize=5, color='m')

universities = [
    ('University College Dublin', 53.3077, -6.2201)
]
for field in universities:
    name, lat, lon = field
    ax.plot(lon, lat, 'ro', markersize=5, color='pink')


universities = [
    ('Sapienza University of Rome', 41.8992, 12.5136),
    ('University of Bologna', 44.4984, 11.3535),
    ('University of Florence', 43.7729, 11.2560),
    ('University of Milan', 45.4789, 9.2285),
    ('University of Padua', 45.4064, 11.8778),
    ('University of Pisa', 43.7170, 10.3970),
    ('University of Turin', 45.0703, 7.6869)
]
for field in universities:
    name, lat, lon = field
    ax.plot(lon, lat, 'ro', markersize=5, color='red')




universities = [
    ('Delft University of Technology', 51.9978, 4.3735),
    ('Erasmus University Rotterdam', 51.9175, 4.5253),
    ('Free University Amsterdam', 52.3330, 4.8654),
    ('Leiden University', 52.1598, 4.4870),
    ('Radboud University', 51.8240, 5.8593),
    ('University of Amsterdam', 52.3592, 4.9081),
    ('University of Groningen', 53.2194, 6.5665),
    ('Utrecht University', 52.0806, 5.1214),
    ('Wageningen University', 51.9665, 5.6668)
]

for field in universities:
    name, lat, lon = field
    ax.plot(lon, lat, 'ro', markersize=5, color='green')

universities = [
    ('Norwegian University of Science and Technology', 63.4169, 10.4027),
    ('University of Bergen', 60.3881, 5.3319),
    ('University of Oslo', 59.9406, 10.7206)
]
for field in universities:
    name, lat, lon = field
    ax.plot(lon, lat, 'ro', markersize=5, color='orange')


universities = [
    ('University of Warsaw', 52.2072, 21.0083)
]
for field in universities:
    name, lat, lon = field
    ax.plot(lon, lat, 'ro', markersize=5, color='yellow')

universities = [
    ('Moscow State University', 55.7033, 37.5306)
]
for field in universities:
    name, lat, lon = field
    ax.plot(lon, lat, 'ro', markersize=5, color='m')

universities = [
    ('Autonomous University of Barcelona', 41.5009, 2.1046),
    ('Complutense University of Madrid', 40.4485, -3.7274),
    ('University of Barcelona', 41.3875, 2.1696),
    ('University of Valencia', 39.4817, -0.3417)
]
for field in universities:
    name, lat, lon = field
    ax.plot(lon, lat, 'ro', markersize=5, color='brown')



universities = [
    ('Karolinska Institute', 59.3451, 18.0586),
    ('KTH Royal Institute of Technology', 59.3470, 18.0723),
    ('Lund University', 55.7113, 13.2113),
    ('Stockholm University', 59.3651, 18.0522),
    ('University of Gothenburg', 57.6883, 11.9770),
    ('Uppsala University', 59.8586, 17.6389)
]
for field in universities:
    name, lat, lon = field
    ax.plot(lon, lat, 'ro', markersize=5, color='gray')




universities = [
    ('Federal Institute of Technology Lausanne', 46.5197, 6.5665),
    ('Swiss Federal Institute of Technology Zurich', 47.3769, 8.5482),
    ('University of Basel', 47.5584, 7.5733),
    ('University of Bern', 46.9504, 7.4399),
    ('University of Geneva', 46.2044, 6.1432),
    ('University of Lausanne', 46.5191, 6.5667),
    ('University of Zurich', 47.3769, 8.5417)
]
for field in universities:
    name, lat, lon = field
    ax.plot(lon, lat, 'ro', markersize=5, color='black')



universities = [
    ('Cardiff University', 51.4816, -3.1791),
    ('Durham University', 54.7753, -1.5849),
    ('Imperial College London', 51.4989, -0.1756),
    ("King's College London", 51.5113, -0.1160),
    ('London School of Economics and Political Science', 51.5143, -0.1169),
    ('Newcastle University', 54.9791, -1.6141),
    ('Queen Mary University of London', 51.5245, -0.0391),
    ('University College London', 51.5242, -0.1345),
    ('University of Birmingham', 52.4508, -1.9305),
    ('University of Bristol', 51.4553, -2.5957),
    ('University of Cambridge', 52.2043, 0.1149),
    ('University of Edinburgh', 55.9444, -3.1870),
    ('University of Exeter', 50.7361, -3.5353),
    ('University of Glasgow', 55.8721, -4.2884),
    ('University of Leeds', 53.8061, -1.5554),
    ('University of Leicester', 52.6205, -1.1240),
    ('University of Liverpool', 53.4084, -2.9916),
    ('University of London', 51.5244, -0.1349),
    ('University of Manchester', 53.4668, -2.2339),
    ('University of Nottingham', 52.9386, -1.1956),
    ('University of Oxford', 51.7548, -1.2544),
    ('University of Sheffield', 53.3813, -1.4902),
    ('University of Southampton', 50.9341, -1.3959),
    ('University of St Andrews', 56.3398, -2.7925),
    ('University of Sussex', 50.8614, -0.0876),
    ('University of Warwick', 52.3790, -1.5609),
    ('University of York', 53.9459, -1.0543)
]
for field in universities:
    name, lat, lon = field
    ax.plot(lon, lat, 'ro', markersize=5, color='cyan')

# Show the map
plt.show()
# Out:
# C:\Users\TUAN\AppData\Local\Temp\ipykernel_624\1352116655.py:29: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(lon, lat, 'ro', markersize=5, color='red')
# C:\Users\TUAN\AppData\Local\Temp\ipykernel_624\1352116655.py:38: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(lon, lat, 'ro', markersize=5,color='cyan')
# C:\Users\TUAN\AppData\Local\Temp\ipykernel_624\1352116655.py:45: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(lon, lat, 'ro', markersize=5,color='brown')
# ...
